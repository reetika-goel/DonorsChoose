# %% [markdown]
# ### Web Scraping using Beautiful Soup
#
# Objective : DonorsChoose.org is an organization which collects funds from people to help public schools in America. Below we have scraped the https://www.niche.com/ website to get more information about schools, which will help in enhancing our DonorsChoose datasets to get more insights.

# %% [markdown]
# #### Import libraries

# %%
# import libraries
import urllib.request
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd
import csv
from datetime import datetime
import re

# %% [markdown]
# #### Get Data from the URL using BeautifulSoup
# @Author : Pragya & Sithara

# %%
def getData(url):

  #we use the html parser to parse the url content and store it in a variable.
  textContent = []
  validate = lambda x : x.text if x is not None else np.nan

  for i in range(386): 
    i=i+1 # Number of pages plus one 
    #url = url.format(i)
    #https://www.niche.com/k12/search/best-schools/s/texas/?type=traditional&type=charter&type=magnet&gradeLevel=pk&gradeLevel=elementary&gradeLevel=middle&gradeLevel=high&page={}
    #https://www.niche.com/k12/search/best-schools/s/california/?gradeLevel=pk&gradeLevel=elementary&gradeLevel=middle&gradeLevel=high&type=traditional&type=charter&type=magnet
    url = "https://www.niche.com/k12/search/best-schools/s/california/?gradeLevel=pk&gradeLevel=elementary&gradeLevel=middle&gradeLevel=high&type=traditional&type=charter&type=magnet&page={}".format(i)
    #print(i)
    #print(url)
    with urllib.request.urlopen(url) as response:
      page = response.read()

    # parse the html using beautiful soup and store in variable `soup`
    soup = BeautifulSoup(page, 'html.parser')

    #Get the Data from the html
    mydivs = soup.findAll("li", {"class": "search-results__list__item"})
    for li in mydivs:
      if(li != None):
        unwanted = li.findAll(True, {"class":["search-result--featured","illustrated-cta","ad-spot", "ad-spot--mobile", "ad-spot--inactive", "search-related-lists"]})
        if (len(unwanted) > 0):
          continue
        name = li.find("h2",{"class":"search-result__title"})
        schoolName = validate(name)
        if('.' in schoolName):
          schoolName = schoolName.replace('.','')
        rank = li.find("div",{"class":"search-result-badge"})
        schoolRank = validate(rank)
        #print(schoolRank)
        tagline = li.find("ul", {"class":"search-result-tagline"})
        if(tagline !=None):
          ratingSpan = tagline.find("span", {"class":"review__stars__icon"})
          rating = (int)(ratingSpan['class'][1][-2:])/10 if (ratingSpan !=None) else np.nan 
          #print(rating)
          reviewCountSpan = tagline.find("span", {"class":"review__stars__number__reviews"})
          reviewCount = validate(reviewCountSpan)
        district = tagline.find(string=re.compile("[A-Z]$"))
        #schoolDistrict = district if (district !=None) else np.nan
        S_District = district if (district !=None) else np.nan
        result = [x.strip() for x in S_District.split(',')]
        schoolDistrict = result[0].replace('Independent', 'Ind')
        #print(schoolDistrict)
        schoolState = result[1]
        #print(schoolState)
        #print(schoolDistrict)
        level = tagline.find(string=re.compile("[A-Z0-9][-]{1}[0-9]"))
        schoolGradeLevel = level if (level !=None) else np.nan
        #print(schoolGradeLevel)
        schoolGrades = li.findAll("li",{"class":"search-result-fact-list__item"})
        grade = li.find("ul",{"class":"search-result-fact-list"}).find("div",{"class":"niche__grade"})
        schoolGrade = validate(grade)
        studentCount = schoolGrades[1].find("span",{"class":"search-result-fact__value"})
        schoolStrength = validate(studentCount)
        stRatio = schoolGrades[2].find("span",{"class":"search-result-fact__value"})
        studentTeacherRatio = validate(stRatio)
        #print(studentTeacherRatio)

        textContent.append((schoolName, schoolRank, schoolDistrict,schoolState, schoolGradeLevel, rating, reviewCount, schoolGrade, schoolStrength, studentTeacherRatio))
    
  return textContent

# %%
url = "https://www.niche.com/k12/search/best-schools/s/texas/?type=traditional&type=charter&type=magnet&gradeLevel=pk&gradeLevel=elementary&gradeLevel=middle&gradeLevel=high&page={}"
textContent = getData(url)

# %%
print('\n'.join(map(str, textContent)))
# Out:
# ('Canyon Crest Academy', '#16 Best Public High Schools in America', 'San Dieguito Union High School District', 'CA', '9-12', 4.5, '495', 'A+', '2,255', '26:1')
# ('Henry M Gunn High School', '#21 Best Public High Schools in America', 'Palo Alto Unified School District', 'CA', '9-12', 4.0, '260', 'A+', '1,918', '19:1')
# ('Troy High School', '#42 Best Public High Schools in America', 'Fullerton Joint Union High School District', 'CA', '9-12', 4.0, '794', 'A+', '2,755', '27:1')
# ('Palo Alto High School', '#51 Best Public High Schools in America', 'Palo Alto Unified School District', 'CA', '9-12', 4.0, '280', 'A+', '1,993', '19:1')
# ('Miramonte High School', '#57 Best Public High Schools in America', 'Acalanes Union High School District', 'CA', '9-12', 4.0, '190', 'A+', '1,232', '20:1')
# ('Northwood High School', '#67 Best Public High Schools in America', 'Irvine Unified School District', 'CA', '9-12', 4.0, '457', 'A+', '2,240', '28:1')
# ('Saratoga High School', '#77 Best Public High Schools in America', 'Los Gatos-Saratoga Joint Union High School District', 'CA', '9-12', 4.0, '157', 'A+', '1,305', '18:1')
# ('Torrey Pines High School', '#80 Best Public High Schools in America', 'San Dieguito Union High School District', 'CA', '9-12', 4.0, '401', 'A+', '2,601', '27:1')
# ('Palos Verdes Peninsula High School', '#94 Best Public High Schools in America', 'Palos Verdes Peninsula Unified School District', 'CA', '9-12', 4.0, '576', 'A+', '2,519', '26:1')
# ('Los Altos High School', '#101 Best Public High Schools in America', 'Mountain View-Los Altos Union High School District', 'CA', '9-12', 4.0, '263', 'A+', '2,039', '21:1')
# ('Westview High School', '#105 Best Public High Schools in America', 'Poway Unified School District', 'CA', '9-12', 4.0, '574', 'A+', '2,304', '28:1')
# ('California Academy of Mathematics & Science', '#106 Best Public High Schools in America', 'Long Beach Unified School District', 'CA', '9-12', 4.0, '398', 'A+', '681', '30:1')
# ('Los Gatos High School', '#108 Best Public High Schools in America', 'Los Gatos-Saratoga Joint Union High School District', 'CA', '9-12', 4.0, '222', 'A+', '1,975', '22:1')
# ('Lynbrook High School', '#117 Best Public High Schools in America', 'Fremont Union High School District', 'CA', '9-12', 3.5, '418', 'A+', '1,766', '24:1')
# ('Granada Hills Charter High School', '#120 Best Public High Schools in America', 'Los Angeles Unified School District', 'CA', '9-12', 4.0, '1,230', 'A+', '4,650', '19:1')
# ('Campolindo High School', '#128 Best Public High Schools in America', 'Acalanes Union High School District', 'CA', '9-12', 4.0, '236', 'A+', '1,300', '21:1')
# ('San Marino High School', '#129 Best Public High Schools in America', 'San Marino Unified School District', 'CA', '9-12', 4.0, '244', 'A+', '1,200', '21:1')
# ('La Canada High School', '#134 Best Public High Schools in America', 'La Canada Unified School District', 'CA', '7-12', 3.5, '308', 'A+', '2,075', '25:1')
# ('Carmel High School', '#152 Best Public High Schools in America', 'Carmel Unified School District', 'CA', '9-12', 4.0, '205', 'A+', '857', '17:1')
# ('Lowell High School', '#156 Best Public High Schools in America', 'San Francisco Unified School District', 'CA', '9-12', 3.5, '890', 'A+', '2,685', '21:1')
# ('Redwood High School', '#160 Best Public High Schools in America', 'Tamalpais Union High School District', 'CA', '9-12', 4.0, '187', 'A+', '1,770', '19:1')
# ('Arcadia High School', '#163 Best Public High Schools in America', 'Arcadia Unified School District', 'CA', '9-12', 4.0, '984', 'A+', '3,424', '25:1')
# ('University High School', '#174 Best Public High Schools in America', 'Fresno Unified School District', 'CA', '9-12', 4.0, '220', 'A+', '482', '25:1')
# ('Orange County School of the Arts', '#182 Best Public High Schools in America', 'Santa Ana Unified School District', 'CA', '7-12', 4.0, '459', 'A+', '2,096', '30:1')
# ('Amador Valley High School', '#184 Best Public High Schools in America', 'Pleasanton Unified School District', 'CA', '9-12', 4.0, '441', 'A+', '2,628', '25:1')
# ('University High School', '#199 Best Public High Schools in America', 'Irvine Unified School District', 'CA', '9-12', 4.0, '437', 'A+', '2,617', '27:1')
# ('Oxford Academy', '#206 Best Public High Schools in America', 'Anaheim Union High School District', 'CA', '7-12', 3.5, '572', 'A+', '1,208', '28:1')
# ('Whitney High School', '#210 Best Public High Schools in America', 'ABC Unified School District', 'CA', '7-12', 3.5, '333', 'A+', '1,011', '25:1')
# ('Dougherty Valley High School', '#211 Best Public High Schools in America', 'San Ramon Valley Unified School District', 'CA', '9-12', 3.5, '578', 'A+', '2,759', '24:1')
# ('Walnut High School', '#226 Best Public High Schools in America', 'Walnut Valley Unified School District', 'CA', '9-12', 4.0, '537', 'A+', '2,675', '24:1')
# ('Academy of the Canyons', '#228 Best Public High Schools in America', 'William S. Hart Union High School District', 'CA', '9-12', 4.0, '203', 'A+', '395', '33:1')
# ('Westlake High School', '#233 Best Public High Schools in America', 'Conejo Valley Unified School District', 'CA', '9-12', 4.0, '419', 'A+', '2,370', '28:1')
# ('Monta Vista High School', '#251 Best Public High Schools in America', 'Fremont Union High School District', 'CA', '9-12', 3.5, '353', 'A+', '2,322', '26:1')
# ('Mountain View High School', '#254 Best Public High Schools in America', 'Mountain View-Los Altos Union High School District', 'CA', '9-12', 4.0, '248', 'A+', '1,857', '20:1')
# ('Aragon High School', '#259 Best Public High Schools in America', 'San Mateo Union High School District', 'CA', '9-12', 4.0, '235', 'A+', '1,473', '21:1')
# ('Del Norte High School', '#260 Best Public High Schools in America', 'Poway Unified School District', 'CA', '9-12', 4.0, '328', 'A+', '2,032', '28:1')
# ('Burlingame High School', '#262 Best Public High Schools in America', 'San Mateo Union High School District', 'CA', '9-12', 4.0, '204', 'A+', '1,339', '20:1')
# ('Mission San Jose High School', '#266 Best Public High Schools in America', 'Fremont Unified School District', 'CA', '9-12', 3.5, '336', 'A+', '2,069', '25:1')
# ('Corona Del Mar High School', '#270 Best Public High Schools in America', 'Newport-Mesa Unified School District', 'CA', '7-12', 4.0, '247', 'A+', '2,580', '28:1')
# ('South Pasadena Senior High School', '#274 Best Public High Schools in America', 'South Pasadena Unified School District', 'CA', '9-12', 3.5, '392', 'A+', '1,528', '22:1')
# ('Cupertino High School', '#275 Best Public High Schools in America', 'Fremont Union High School District', 'CA', '9-12', 4.0, '402', 'A+', '2,233', '25:1')
# ('El Carmelo Elementary School', '#18 Best Public Elementary Schools in America', 'Palo Alto Unified School District', 'CA', 'K-5', 5.0, '1', 'A+', '395', '21:1')
# ('Jane Lathrop Stanford Middle School', '#23 Best Public Middle Schools in America', 'Palo Alto Unified School District', 'CA', '6-8', 3.5, '6', 'A+', '1,111', '18:1')
# ('Leland High School', '#295 Best Public High Schools in America', 'San Jose Unified School District', 'CA', '9-12', 3.5, '260', 'A+', '1,807', '25:1')
# ('Duveneck Elementary School', '#21 Best Public Elementary Schools in America', 'Palo Alto Unified School District', 'CA', 'K-5', nan, nan, 'A+', '479', '20:1')
# ('Davis Senior High School', '#305 Best Public High Schools in America', 'Davis Joint Unified School District', 'CA', '10-12', 3.5, '316', 'A+', '1,683', '25:1')
# ('Walter Hays Elementary School', '#23 Best Public Elementary Schools in America', 'Palo Alto Unified School District', 'CA', 'K-5', nan, nan, 'A+', '463', '18:1')
# ('Diamond Bar High School', '#316 Best Public High Schools in America', 'Walnut Valley Unified School District', 'CA', '9-12', 4.0, '703', 'A+', '3,061', '27:1')
# ('Juana Briones Elementary School', '#26 Best Public Elementary Schools in America', 'Palo Alto Unified School District', 'CA', 'K-5', nan, nan, 'A+', '335', '19:1')
# ('Arnold O Beckman High School', '#327 Best Public High Schools in America', 'Tustin Unified School District', 'CA', '9-12', 4.0, '631', 'A+', '2,847', '27:1')
# ('Fairmeadow Elementary School', '#31 Best Public Elementary Schools in America', 'Palo Alto Unified School District', 'CA', 'K-5', 5.0, '2', 'A+', '514', '21:1')
# ('Herbert Hoover Elementary School', '#36 Best Public Elementary Schools in America', 'Palo Alto Unified School District', 'CA', 'K-5', nan, nan, 'A+', '406', '21:1')
# ('Ohlone Elementary School', '#37 Best Public Elementary Schools in America', 'Palo Alto Unified School District', 'CA', 'K-5', 4.0, '1', 'A+', '600', '20:1')
# ('Ellen Fletcher Middle School', '#29 Best Public Middle Schools in America', 'Palo Alto Unified School District', 'CA', '6-8', 4.5, '3', 'A+', '751', '17:1')
# ('Lucille M Nixon Elementary School', '#40 Best Public Elementary Schools in America', 'Palo Alto Unified School District', 'CA', 'K-5', nan, nan, 'A+', '473', '19:1')
# ('Frank S Greene Jr Middle School', '#32 Best Public Middle Schools in America', 'Palo Alto Unified School District', 'CA', '6-8', 3.0, '9', 'A+', '1,130', '16:1')
# ('Palo Verde Elementary School', '#42 Best Public Elementary Schools in America', 'Palo Alto Unified School District', 'CA', 'K-5', 5.0, '1', 'A+', '415', '21:1')
# ('Pacific Collegiate Charter School', '#356 Best Public High Schools in America', 'Santa Cruz', 'CA', '7-12', 3.5, '72', 'A+', '518', '18:1')
# ('Albany High School', '#357 Best Public High Schools in America', 'Albany City Unified School District', 'CA', '9-12', 3.5, '257', 'A+', '1,208', '19:1')
# ('Coronado High School', '#360 Best Public High Schools in America', 'Coronado Unified School District', 'CA', '9-12', 4.0, '232', 'A+', '1,231', '22:1')
# ('Woodbridge High School', '#371 Best Public High Schools in America', 'Irvine Unified School District', 'CA', '9-12', 4.0, '408', 'A+', '2,447', '26:1')
# ('Carlmont High School', '#372 Best Public High Schools in America', 'Sequoia Union High School District', 'CA', '9-12', 4.0, '272', 'A+', '2,147', '22:1')
# ('Foothill High School', '#376 Best Public High Schools in America', 'Pleasanton Unified School District', 'CA', '9-12', 4.0, '345', 'A+', '2,085', '24:1')
# ('Acalanes High School', '#379 Best Public High Schools in America', 'Acalanes Union High School District', 'CA', '9-12', 4.0, '170', 'A+', '1,403', '20:1')
# ('Addison Elementary School', '#57 Best Public Elementary Schools in America', 'Palo Alto Unified School District', 'CA', 'K-5', nan, nan, 'A+', '475', '21:1')
# ('San Dieguito High Academy', '#393 Best Public High Schools in America', 'San Dieguito Union High School District', 'CA', '9-12', 4.5, '417', 'A+', '1,828', '24:1')
# ('Homestead High School', '#397 Best Public High Schools in America', 'Fremont Union High School District', 'CA', '9-12', 3.5, '401', 'A+', '2,367', '25:1')
# ('Piedmont High School', '#416 Best Public High Schools in America', 'Piedmont City Unified School District', 'CA', '9-12', 3.5, '73', 'A+', '800', '18:1')
# ('Escondido Elementary School', '#102 Best Public Elementary Schools in America', 'Palo Alto Unified School District', 'CA', 'K-5', nan, nan, 'A+', '550', '20:1')
# ('Mira Costa High School', '#431 Best Public High Schools in America', 'Manhattan Beach Unified School District', 'CA', '9-12', 3.5, '504', 'A+', '2,437', '23:1')
# ('Beverly Hills High School', '#433 Best Public High Schools in America', 'Beverly Hills Unified School District', 'CA', '9-12', 3.5, '297', 'A+', '1,589', '17:1')
# ('Crescenta Valley High School', '#436 Best Public High Schools in America', 'Glendale Unified School District', 'CA', '9-12', 4.0, '553', 'A+', '2,670', '29:1')
# ('Woodside Elementary School', '#111 Best Public Elementary Schools in America', 'Woodside', 'CA', 'K-8', 4.5, '4', 'A+', '409', '11:1')
# ('Cerritos High School', '#443 Best Public High Schools in America', 'ABC Unified School District', 'CA', '9-12', 3.5, '533', 'A+', '2,132', '24:1')
# ('San Mateo High School', '#447 Best Public High Schools in America', 'San Mateo Union High School District', 'CA', '9-12', 4.0, '218', 'A+', '1,615', '21:1')
# ('Grossmont Middle College High School', '#449 Best Public High Schools in America', 'Grossmont Union High School District', 'CA', '11-12', 4.0, '130', 'A+', '70', '18:1')
# ('Fountain Valley High School', '#452 Best Public High Schools in America', 'Huntington Beach Union High School District', 'CA', '9-12', 4.0, '735', 'A+', '3,558', '29:1')
# ('University Preparatory Academy Charter School', '#457 Best Public High Schools in America', 'San Jose', 'CA', '7-12', 3.5, '144', 'A+', '593', '22:1')
# ('Valencia High School', '#459 Best Public High Schools in America', 'Placentia-Yorba Linda Unified School District', 'CA', '9-12', 4.0, '393', 'A+', '2,797', '27:1')
# ('Sage Creek High School', '#461 Best Public High Schools in America', 'Carlsbad Unified School District', 'CA', '9-12', 4.5, '41', 'A+', '1,000', '26:1')
# ('Tamalpais High School', '#476 Best Public High Schools in America', 'Tamalpais Union High School District', 'CA', '9-12', 4.0, '176', 'A+', '1,419', '21:1')
# ('Los Alamitos High School', '#487 Best Public High Schools in America', 'Los Alamitos Unified School District', 'CA', '9-12', 4.0, '798', 'A+', '3,336', '28:1')
# ('Pacific Trails Middle School', '#78 Best Public Middle Schools in America', 'San Dieguito Union High School District', 'CA', '7-8', nan, nan, 'A+', '264', '23:1')
# ('Tesoro High School', '#499 Best Public High Schools in America', 'Capistrano Unified School District', 'CA', '9-12', 4.0, '349', 'A+', '2,451', '28:1')
# ('Irvine High School', '#503 Best Public High Schools in America', 'Irvine Unified School District', 'CA', '9-12', 4.0, '355', 'A+', '2,031', '27:1')
# ('Dublin High School', '#507 Best Public High Schools in America', 'Dublin Unified School District', 'CA', '9-12', 3.5, '358', 'A+', '2,252', '22:1')
# ('Mira Loma High School', '#508 Best Public High Schools in America', 'San Juan Unified School District', 'CA', '9-12', 3.5, '316', 'A+', '1,681', '26:1')
# ('Carver Elementary School', '#198 Best Public Elementary Schools in America', 'San Marino Unified School District', 'CA', 'K-5', 4.5, '2', 'A+', '586', '22:1')
# ('Monte Vista High School', '#523 Best Public High Schools in America', 'San Ramon Valley Unified School District', 'CA', '9-12', 4.0, '241', 'A+', '2,348', '23:1')
# ('Riverside STEM Academy', '#524 Best Public High Schools in America', 'Riverside Unified School District', 'CA', '5-12', 4.5, '25', 'A+', '577', '26:1')
# ('Rancho Bernardo High School', '#529 Best Public High Schools in America', 'Poway Unified School District', 'CA', '9-12', 4.0, '464', 'A+', '2,265', '28:1')
# ('Santa Monica High School', '#531 Best Public High Schools in America', 'Santa Monica-Malibu Unified School District', 'CA', '9-12', 4.0, '684', 'A+', '2,950', '23:1')
# ('University Preparatory', '#536 Best Public High Schools in America', 'Shasta Union High School District', 'CA', '6-12', 4.0, '177', 'A+', '967', '23:1')
# ('Preuss School UCSD', '#538 Best Public High Schools in America', 'San Diego Unified School District', 'CA', '6-12', 4.0, '253', 'A+', '840', '21:1')
# ('Carmel Middle School', '#107 Best Public Middle Schools in America', 'Carmel Unified School District', 'CA', '6-8', nan, nan, 'A+', '559', '15:1')
# ('Folsom High School', '#552 Best Public High Schools in America', 'Folsom-Cordova Unified School District', 'CA', '9-12', 4.0, '412', 'A+', '2,300', '26:1')
# ('Huntington Middle School', '#108 Best Public Middle Schools in America', 'San Marino Unified School District', 'CA', '6-8', 4.5, '13', 'A+', '780', '21:1')
# ('Mt Carmel High School', '#560 Best Public High Schools in America', 'Poway Unified School District', 'CA', '9-12', 4.0, '323', 'A+', '1,960', '27:1')
# ('San Juan Hills High School', '#564 Best Public High Schools in America', 'Capistrano Unified School District', 'CA', '9-12', 4.0, '358', 'A+', '2,392', '27:1')
# ('Palm Crest Elementary School', '#282 Best Public Elementary Schools in America', 'La Canada Unified School District', 'CA', 'K-6', nan, nan, 'A+', '614', '22:1')
# ('Deer Canyon Elementary School', '#302 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', nan, nan, 'A+', '504', '24:1')
# ('R Roger Rowe Middle School', '#122 Best Public Middle Schools in America', 'Rancho Santa Fe Elementary School District', 'CA', '6-8', nan, nan, 'A+', '248', '11:1')
# ('High Tech Los Angeles', '#588 Best Public High Schools in America', 'Los Angeles Unified School District', 'CA', '9-12', 4.0, '127', 'A+', '390', '24:1')
# ('Mt Everest Academy', '#590 Best Public High Schools in America', 'San Diego Unified School District', 'CA', 'K-12', 4.0, '40', 'A+', '263', '19:1')
# ('Mills High School', '#597 Best Public High Schools in America', 'San Mateo Union High School District', 'CA', '9-12', 3.5, '235', 'A+', '1,198', '21:1')
# ('Granite Bay High School', '#598 Best Public High Schools in America', 'Roseville Joint Union High School District', 'CA', '9-12', 4.0, '281', 'A+', '2,043', '24:1')
# ('Las Lomas High School', '#601 Best Public High Schools in America', 'Acalanes Union High School District', 'CA', '9-12', 4.0, '230', 'A+', '1,528', '20:1')
# ('Menlo-Atherton High School', '#606 Best Public High Schools in America', 'Sequoia Union High School District', 'CA', '9-12', 3.5, '230', 'A+', '2,275', '20:1')
# ('Foothills Middle School', '#133 Best Public Middle Schools in America', 'Arcadia Unified School District', 'CA', '6-8', 3.5, '9', 'A+', '770', '24:1')
# ('Los Penasquitos Elementary School', '#338 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', nan, nan, 'A+', '551', '26:1')
# ('Berkeley High School', '#614 Best Public High Schools in America', 'Berkeley Unified School District', 'CA', '9-12', 4.0, '437', 'A+', '3,113', '18:1')
# ('Alameda Science and Technology Institute', '#619 Best Public High Schools in America', 'Alameda City Unified School District', 'CA', '9-12', 4.0, '67', 'A+', '175', '29:1')
# ('Palos Verdes High School', '#626 Best Public High Schools in America', 'Palos Verdes Peninsula Unified School District', 'CA', '9-12', 4.0, '354', 'A+', '1,716', '24:1')
# ('Irvington High School', '#636 Best Public High Schools in America', 'Fremont Unified School District', 'CA', '9-12', 3.5, '622', 'A+', '2,253', '25:1')
# ('Carmel River Elementary School', '#380 Best Public Elementary Schools in America', 'Carmel Unified School District', 'CA', 'K-5', nan, nan, 'A+', '455', '21:1')
# ('Willow Grove Elementary School', '#382 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', nan, nan, 'A+', '764', '25:1')
# ('Clovis North High School', '#642 Best Public High Schools in America', 'Clovis Unified School District', 'CA', '9-12', 4.0, '308', 'A+', '2,459', '24:1')
# ('R Roger Rowe Elementary School', '#386 Best Public Elementary Schools in America', 'Rancho Santa Fe Elementary School District', 'CA', 'K-5', 5.0, '2', 'A+', '427', '17:1')
# ('La Canada Elementary School', '#392 Best Public Elementary Schools in America', 'La Canada Unified School District', 'CA', 'K-6', 3.5, '3', 'A+', '672', '24:1')
# ('Carmel Valley Middle School', '#158 Best Public Middle Schools in America', 'San Dieguito Union High School District', 'CA', '7-8', 4.0, '4', 'A+', '1,361', '27:1')
# ('Creekside Elementary School', '#399 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', nan, nan, 'A+', '564', '25:1')
# ('Redondo Union High School', '#648 Best Public High Schools in America', 'Redondo Beach Unified School District', 'CA', '9-12', 4.0, '560', 'A+', '2,755', '26:1')
# ('Oak Park High School', '#649 Best Public High Schools in America', 'Oak Park Unified School District', 'CA', '9-12', 4.0, '292', 'A+', '1,542', '24:1')
# ('Paradise Canyon Elementary School', '#431 Best Public Elementary Schools in America', 'La Canada Unified School District', 'CA', 'K-6', nan, nan, 'A+', '717', '24:1')
# ('Yorba Linda High School', '#667 Best Public High Schools in America', 'Placentia-Yorba Linda Unified School District', 'CA', '9-12', 4.0, '326', 'A+', '1,791', '27:1')
# ('Aliso Niguel High School', '#669 Best Public High Schools in America', 'Capistrano Unified School District', 'CA', '9-12', 4.0, '657', 'A+', '3,068', '29:1')
# ('Dos Pueblos Senior High School', '#674 Best Public High Schools in America', 'Santa Barbara Unified School District', 'CA', '9-12', 4.0, '409', 'A+', '2,130', '24:1')
# ('Monterey Ridge Elementary School', '#452 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', nan, nan, 'A+', '1,038', '26:1')
# ('Highland Oaks Elementary School', '#460 Best Public Elementary Schools in America', 'Arcadia Unified School District', 'CA', 'K-5', nan, nan, 'A+', '680', '25:1')
# ('Stone Ranch Elementary School', '#477 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', 5.0, '1', 'A+', '956', '26:1')
# ('Western Sierra Collegiate Academy', '#692 Best Public High Schools in America', 'Rocklin Academy Family of Schools', 'CA', '6-12', 3.5, '102', 'A+', '728', '23:1')
# ('Turtle Rock Elementary School', '#487 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-6', 4.0, '1', 'A+', '883', '29:1')
# ('Foothill Technology High School', '#693 Best Public High Schools in America', 'Ventura Unified School District', 'CA', '9-12', 4.0, '252', 'A+', '1,023', '28:1')
# ('Great Oak High School', '#695 Best Public High Schools in America', 'Temecula Valley Unified School District', 'CA', '9-12', 4.0, '718', 'A+', '3,473', '27:1')
# ('Rancho San Joaquin Middle School', '#193 Best Public Middle Schools in America', 'Irvine Unified School District', 'CA', '7-8', 4.5, '3', 'A+', '863', '28:1')
# ('Vista Verde', '#499 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-8', 4.5, '2', 'A+', '947', '28:1')
# ('Bonita Canyon Elementary School', '#500 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-6', 4.0, '1', 'A+', '488', '28:1')
# ('Temple City High School', '#699 Best Public High Schools in America', 'Temple City Unified School District', 'CA', '9-12', 3.5, '392', 'A+', '2,076', '25:1')
# ('Oak Valley Middle School', '#197 Best Public Middle Schools in America', 'Poway Unified School District', 'CA', '6-8', 3.0, '14', 'A+', '1,388', '27:1')
# ('Solana Highlands Elementary School', '#518 Best Public Elementary Schools in America', 'Solana Beach Elementary School District', 'CA', 'K-3', 5.0, '1', 'A+', '353', '20:1')
# ('West Ranch High School', '#710 Best Public High Schools in America', 'William S. Hart Union High School District', 'CA', '9-12', 4.0, '582', 'A+', '2,455', '27:1')
# ('Opal Robinson Elementary School', '#532 Best Public Elementary Schools in America', 'Manhattan Beach Unified School District', 'CA', 'K-5', nan, nan, 'A+', '408', '24:1')
# ('Point Vicente Elementary School', '#540 Best Public Elementary Schools in America', 'Palos Verdes Peninsula Unified School District', 'CA', 'K-5', 5.0, '7', 'A+', '374', '23:1')
# ('Pleasanton Middle School', '#212 Best Public Middle Schools in America', 'Pleasanton Unified School District', 'CA', '6-8', 2.0, '3', 'A+', '1,272', '23:1')
# ('Del Sur Elementary School', '#543 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', 5.0, '2', 'A+', '705', '27:1')
# ('Mission Vista High School', '#716 Best Public High Schools in America', 'Vista Unified School District', 'CA', '9-12', 4.0, '460', 'A+', '1,566', '21:1')
# ('Park Village Elementary School', '#551 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', 5.0, '1', 'A+', '635', '25:1')
# ('Sir Francis Drake High School', '#719 Best Public High Schools in America', 'Tamalpais Union High School District', 'CA', '9-12', 4.0, '226', 'A+', '1,077', '19:1')
# ('Los Angeles Center for Enriched Studies', '#720 Best Public High Schools in America', 'Los Angeles Unified School District', 'CA', '6-12', 3.5, '374', 'A+', '1,648', '25:1')
# ('Valentine Elementary School', '#555 Best Public Elementary Schools in America', 'San Marino Unified School District', 'CA', 'K-5', 4.0, '6', 'A+', '561', '22:1')
# ('Lakeside Middle School', '#218 Best Public Middle Schools in America', 'Irvine Unified School District', 'CA', '7-8', 3.0, '1', 'A+', '656', '25:1')
# ('Sunny Hills High School', '#724 Best Public High Schools in America', 'Fullerton Joint Union High School District', 'CA', '9-12', 4.0, '464', 'A+', '2,307', '30:1')
# ('Cornerstone at Pedregal Elementary School', '#581 Best Public Elementary Schools in America', 'Palos Verdes Peninsula Unified School District', 'CA', 'K-5', 5.0, '1', 'A+', '403', '26:1')
# ('Cold Spring Elementary School', '#588 Best Public Elementary Schools in America', 'Santa Barbara', 'CA', 'K-6', nan, nan, 'A+', '151', '16:1')
# ('Palisades Charter High School', '#736 Best Public High Schools in America', 'Los Angeles Unified School District', 'CA', '9-12', 4.0, '561', 'A+', '2,970', '24:1')
# ('La Costa Canyon High School', '#744 Best Public High Schools in America', 'San Dieguito Union High School District', 'CA', '9-12', 4.0, '429', 'A+', '1,863', '25:1')
# ('Canyon View Elementary School', '#613 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', nan, nan, 'A+', '540', '25:1')
# ('Earl Warren Middle School', '#247 Best Public Middle Schools in America', 'San Dieguito Union High School District', 'CA', '7-8', 5.0, '2', 'A+', '595', '23:1')
# ('Ballard Elementary School', '#626 Best Public Elementary Schools in America', 'Solvang', 'CA', 'K-6', nan, nan, 'A+', '124', '18:1')
# ('Ross Elementary School', '#636 Best Public Elementary Schools in America', 'Ross', 'CA', 'K-8', nan, nan, 'A+', '384', '15:1')
# ('Adobe Bluffs Elementary School', '#638 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', 5.0, '1', 'A+', '352', '23:1')
# ('Hugo Reid Elementary School', '#647 Best Public Elementary Schools in America', 'Arcadia Unified School District', 'CA', 'K-5', nan, nan, 'A+', '562', '28:1')
# ('Diegueno Middle School', '#257 Best Public Middle Schools in America', 'San Dieguito Union High School District', 'CA', '7-8', 4.0, '1', 'A+', '993', '24:1')
# ('Piedmont Hills High School', '#758 Best Public High Schools in America', 'East Side Union High School District', 'CA', '9-12', 3.5, '575', 'A+', '2,178', '25:1')
# ('Montemalaga Elementary School', '#651 Best Public Elementary Schools in America', 'Palos Verdes Peninsula Unified School District', 'CA', 'K-5', 4.0, '6', 'A+', '494', '26:1')
# ('Oak Ridge High School', '#761 Best Public High Schools in America', 'El Dorado Union High School District', 'CA', '9-12', 4.0, '362', 'A+', '2,400', '25:1')
# ('Richard Henry Dana Middle School', '#262 Best Public Middle Schools in America', 'Arcadia Unified School District', 'CA', '6-8', 5.0, '2', 'A+', '743', '25:1')
# ('Jack L Weaver Elementary School', '#661 Best Public Elementary Schools in America', 'Los Alamitos Unified School District', 'CA', 'K-5', 5.0, '1', 'A+', '685', '26:1')
# ('Rancho Vista Elementary School', '#662 Best Public Elementary Schools in America', 'Palos Verdes Peninsula Unified School District', 'CA', 'K-5', 5.0, '1', 'A+', '443', '25:1')
# ('Thousand Oaks High School', '#767 Best Public High Schools in America', 'Conejo Valley Unified School District', 'CA', '9-12', 4.0, '496', 'A+', '2,294', '27:1')
# ('Rolling Hills Elementary School', '#670 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', 4.5, '2', 'A+', '428', '25:1')
# ('Bullis Charter School', '#671 Best Public Elementary Schools in America', 'Los Altos', 'CA', 'K-8', 3.5, '6', 'A+', '744', '19:1')
# ('Richard Henry Lee Elementary School', '#674 Best Public Elementary Schools in America', 'Los Alamitos Unified School District', 'CA', 'K-5', nan, nan, 'A+', '658', '26:1')
# ('South High School', '#774 Best Public High Schools in America', 'Torrance Unified School District', 'CA', '9-12', 3.5, '387', 'A+', '2,069', '23:1')
# ('Eastshore Elementary School', '#679 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-6', nan, nan, 'A+', '621', '30:1')
# ('Jeffrey Trail Middle School', '#269 Best Public Middle Schools in America', 'Irvine Unified School District', 'CA', '7-8', 4.5, '4', 'A+', '999', '28:1')
# ('Carmel Creek Elementary School', '#680 Best Public Elementary Schools in America', 'Solana Beach Elementary School District', 'CA', 'K-3', nan, nan, 'A+', '347', '17:1')
# ('Westpark Elementary School', '#681 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-6', nan, nan, 'A+', '798', '28:1')
# ('Classical Academy High School', '#776 Best Public High Schools in America', 'Escondido Union High School District', 'CA', '9-12', 4.0, '157', 'A+', '1,084', '29:1')
# ('Stone Creek Elementary School', '#683 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-6', 1.0, '1', 'A+', '588', '31:1')
# ('Stonegate Elementary School', '#691 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-6', 1.0, '1', 'A+', '1,031', '30:1')
# ('Aurelia Pennekamp Elementary School', '#702 Best Public Elementary Schools in America', 'Manhattan Beach Unified School District', 'CA', 'K-5', nan, nan, 'A+', '560', '25:1')
# ('California High School', '#790 Best Public High Schools in America', 'San Ramon Valley Unified School District', 'CA', '9-12', 3.5, '538', 'A+', '2,667', '24:1')
# ('Beach Elementary School', '#709 Best Public Elementary Schools in America', 'Piedmont City Unified School District', 'CA', 'K-5', nan, nan, 'A+', '335', '20:1')
# ('Phoebe Apperson Hearst Elementary School', '#712 Best Public Elementary Schools in America', 'Pleasanton Unified School District', 'CA', 'K-5', 2.0, '1', 'A+', '689', '27:1')
# ('Tularcitos Elementary School', '#721 Best Public Elementary Schools in America', 'Carmel Unified School District', 'CA', 'K-5', nan, nan, 'A+', '535', '23:1')
# ('West Hillsborough', '#722 Best Public Elementary Schools in America', 'Hillsborough City Elementary School District', 'CA', 'K-5', nan, nan, 'A+', '381', '21:1')
# ('Scripps Ranch High School', '#800 Best Public High Schools in America', 'San Diego Unified School District', 'CA', '9-12', 3.5, '547', 'A+', '2,221', '26:1')
# ('Laguna Beach High School', '#802 Best Public High Schools in America', 'Laguna Beach Unified School District', 'CA', '9-12', 3.5, '139', 'A+', '1,103', '22:1')
# ('Venado Middle School', '#279 Best Public Middle Schools in America', 'Irvine Unified School District', 'CA', '7-8', 2.0, '1', 'A+', '642', '25:1')
# ('Santiago Hills Elementary School', '#734 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-6', nan, nan, 'A+', '625', '25:1')
# ('Northcoast Preparatory & Performing Arts Academy', '#809 Best Public High Schools in America', 'Arcata', 'CA', '9-12', 4.0, '34', 'A+', '176', '22:1')
# ('New West Charter School', '#814 Best Public High Schools in America', 'Los Angeles', 'CA', '6-12', 4.0, '29', 'A+', '823', '21:1')
# ('Deerfield Elementary School', '#760 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-6', nan, nan, 'A+', '656', '30:1')
# ('William & Marian Ghidotti High School', '#818 Best Public High Schools in America', 'Nevada Joint Union High School District', 'CA', '9-12', 4.5, '75', 'A+', '163', '34:1')
# ('Solana Vista Elementary School', '#773 Best Public Elementary Schools in America', 'Solana Beach Elementary School District', 'CA', 'K-3', nan, nan, 'A+', '466', '19:1')
# ('Meadows Avenue Elementary School', '#780 Best Public Elementary Schools in America', 'Manhattan Beach Unified School District', 'CA', 'K-5', 4.5, '5', 'A+', '431', '24:1')
# ('Black Mountain Middle School', '#307 Best Public Middle Schools in America', 'Poway Unified School District', 'CA', '6-8', nan, nan, 'A+', '1,250', '26:1')
# ('Foothill Elementary School', '#809 Best Public Elementary Schools in America', 'Saratoga Union Elementary School District', 'CA', 'K-5', nan, nan, 'A+', '360', '17:1')
# ('Soleado Elementary School', '#811 Best Public Elementary Schools in America', 'Palos Verdes Peninsula Unified School District', 'CA', 'K-5', nan, nan, 'A+', '459', '27:1')
# ('Oak Crest Middle School', '#314 Best Public Middle Schools in America', 'San Dieguito Union High School District', 'CA', '7-8', 3.5, '8', 'A+', '761', '22:1')
# ('Piedmont Middle School', '#318 Best Public Middle Schools in America', 'Piedmont City Unified School District', 'CA', '6-8', nan, nan, 'A+', '681', '17:1')
# ('West High School', '#829 Best Public High Schools in America', 'Torrance Unified School District', 'CA', '9-12', 3.5, '387', 'A+', '2,073', '24:1')
# ('Mesa Verde Middle School', '#319 Best Public Middle Schools in America', 'Poway Unified School District', 'CA', '6-8', 2.5, '3', 'A+', '1,275', '25:1')
# ('Silver Spur Elementary School', '#822 Best Public Elementary Schools in America', 'Palos Verdes Peninsula Unified School District', 'CA', 'K-5', nan, nan, 'A+', '547', '26:1')
# ('Holly Avenue Elementary School', '#827 Best Public Elementary Schools in America', 'Arcadia Unified School District', 'CA', 'K-5', nan, nan, 'A+', '705', '26:1')
# ('Dapplegray Elementary School', '#832 Best Public Elementary Schools in America', 'Palos Verdes Peninsula Unified School District', 'CA', 'K-5', nan, nan, 'A+', '599', '27:1')
# ('First Avenue Middle School', '#324 Best Public Middle Schools in America', 'Arcadia Unified School District', 'CA', '6-8', 5.0, '2', 'A+', '754', '26:1')
# ('Canyon View Elementary School', '#837 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-6', nan, nan, 'A+', '801', '29:1')
# ('South Hillsborough', '#842 Best Public Elementary Schools in America', 'Hillsborough City Elementary School District', 'CA', 'K-5', 4.5, '2', 'A+', '243', '18:1')
# ('Longley Way Elementary School', '#845 Best Public Elementary Schools in America', 'Arcadia Unified School District', 'CA', 'K-5', nan, nan, 'A+', '494', '23:1')
# ('Vista Grande Elementary School', '#846 Best Public Elementary Schools in America', 'Palos Verdes Peninsula Unified School District', 'CA', 'K-5', nan, nan, 'A+', '439', '26:1')
# ('Sierra Vista Middle School', '#325 Best Public Middle Schools in America', 'Irvine Unified School District', 'CA', '7-8', 3.0, '3', 'A+', '853', '28:1')
# ('Pacific Elementary School', '#857 Best Public Elementary Schools in America', 'Manhattan Beach Unified School District', 'CA', 'K-5', nan, nan, 'A+', '627', '23:1')
# ('South Lake Middle School', '#326 Best Public Middle Schools in America', 'Irvine Unified School District', 'CA', '7-8', nan, nan, 'A+', '706', '25:1')
# ('Escondido Charter High School', '#843 Best Public High Schools in America', 'Escondido Union High School District', 'CA', '9-12', 4.0, '168', 'A+', '765', '17:1')
# ('Westwood Elementary School', '#864 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', nan, nan, 'A+', '794', '25:1')
# ('Ridgecrest Intermediate', '#330 Best Public Middle Schools in America', 'Palos Verdes Peninsula Unified School District', 'CA', '6-8', nan, nan, 'A+', '926', '26:1')
# ('Harvest Park Middle School', '#332 Best Public Middle Schools in America', 'Pleasanton Unified School District', 'CA', '6-8', 3.5, '8', 'A+', '1,192', '24:1')
# ('Rocklin High School', '#847 Best Public High Schools in America', 'Rocklin Unified School District', 'CA', '9-12', 4.0, '350', 'A+', '1,922', '24:1')
# ('Palos Verdes Intermediate', '#334 Best Public Middle Schools in America', 'Palos Verdes Peninsula Unified School District', 'CA', '6-8', 2.0, '1', 'A+', '889', '24:1')
# ('Hillsdale High School', '#850 Best Public High Schools in America', 'San Mateo Union High School District', 'CA', '9-12', 4.0, '258', 'A+', '1,375', '19:1')
# ('Alderwood Elementary School', '#896 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-6', 5.0, '1', 'A+', '847', '29:1')
# ('Las Lomitas Elementary School', '#897 Best Public Elementary Schools in America', 'Las Lomitas Elementary School District', 'CA', 'K-3', nan, nan, 'A+', '579', '20:1')
# ('Alameda High School', '#857 Best Public High Schools in America', 'Alameda City Unified School District', 'CA', '9-12', 3.5, '373', 'A+', '1,682', '22:1')
# ('Rossmoor Elementary School', '#912 Best Public Elementary Schools in America', 'Los Alamitos Unified School District', 'CA', 'K-5', nan, nan, 'A+', '648', '26:1')
# ('Corte Madera', '#347 Best Public Middle Schools in America', 'Portola Valley Elementary School District', 'CA', '4-8', 5.0, '2', 'A+', '356', '17:1')
# ('Quail Summit Elementary School', '#921 Best Public Elementary Schools in America', 'Walnut Valley Unified School District', 'CA', 'K-5', 1.0, '1', 'A+', '663', '28:1')
# ('Portola Springs Elementary School', '#922 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-6', nan, nan, 'A+', '626', '26:1')
# ('Vintage Hills Elementary School', '#929 Best Public Elementary Schools in America', 'Pleasanton Unified School District', 'CA', 'K-5', nan, nan, 'A+', '611', '24:1')
# ('Grand View Elementary School', '#930 Best Public Elementary Schools in America', 'Manhattan Beach Unified School District', 'CA', 'K-5', 2.0, '1', 'A+', '733', '24:1')
# ('Golden View Elementary School', '#944 Best Public Elementary Schools in America', 'San Ramon Valley Unified School District', 'CA', 'K-5', nan, nan, 'A+', '690', '24:1')
# ('Francis Hopkinson Elementary School', '#945 Best Public Elementary Schools in America', 'Los Alamitos Unified School District', 'CA', 'K-5', 5.0, '1', 'A+', '702', '26:1')
# ('Henry P Mohr Elementary School', '#955 Best Public Elementary Schools in America', 'Pleasanton Unified School District', 'CA', 'K-5', nan, nan, 'A+', '621', '27:1')
# ('Meadow Park Elementary School', '#959 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-6', nan, nan, 'A+', '706', '29:1')
# ('Evergreen Elementary School', '#963 Best Public Elementary Schools in America', 'Walnut Valley Unified School District', 'CA', 'K-5', nan, nan, 'A+', '589', '26:1')
# ('Sunol Glen Elementary School', '#967 Best Public Elementary Schools in America', 'Sunol', 'CA', 'K-8', nan, nan, 'A+', '281', '21:1')
# ('Chaparral Elementary School', '#982 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', 4.0, '1', 'A+', '800', '25:1')
# ('Northwood Elementary School', '#985 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-6', nan, nan, 'A+', '697', '29:1')
# ('Barron Park Elementary School', '#989 Best Public Elementary Schools in America', 'Palo Alto Unified School District', 'CA', 'K-5', nan, nan, 'A+', '289', '16:1')
# ('Marina High School', '#877 Best Public High Schools in America', 'Huntington Beach Union High School District', 'CA', '9-12', 4.0, '295', 'A+', '2,408', '26:1')
# ('Brywood Elementary School', '#1,000 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-6', nan, nan, 'A+', '579', '30:1')
# ('Capistrano Valley High School', '#880 Best Public High Schools in America', 'Capistrano Unified School District', 'CA', '9-12', 3.5, '424', 'A+', '2,241', '27:1')
# ('Del Oro High School', '#882 Best Public High Schools in America', 'Placer Union High School District', 'CA', '9-12', 4.0, '245', 'A+', '1,715', '25:1')
# ('Happy Valley Elementary School', '#1,017 Best Public Elementary Schools in America', 'Santa Cruz', 'CA', 'K-6', nan, nan, 'A+', '132', '21:1')
# ('Woodbury Elementary School', '#1,020 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-6', nan, nan, 'A+', '1,110', '30:1')
# ('Redwood Middle School', '#392 Best Public Middle Schools in America', 'Saratoga Union Elementary School District', 'CA', '6-8', 4.0, '6', 'A+', '889', '20:1')
# ('Painted Rock Elementary School', '#1,024 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', nan, nan, 'A+', '680', '25:1')
# ('Saratoga Elementary School', '#1,037 Best Public Elementary Schools in America', 'Saratoga Union Elementary School District', 'CA', 'K-5', nan, nan, 'A', '355', '19:1')
# ('Camino Grove Elementary School', '#1,041 Best Public Elementary Schools in America', 'Arcadia Unified School District', 'CA', 'K-5', nan, nan, 'A', '628', '26:1')
# ('Baldwin Stocker Elementary School', '#1,054 Best Public Elementary Schools in America', 'Arcadia Unified School District', 'CA', 'K-5', 5.0, '2', 'A', '709', '27:1')
# ('Solana Ranch School', '#1,058 Best Public Elementary Schools in America', 'Solana Beach Elementary School District', 'CA', 'K-6', nan, nan, 'A', '529', '22:1')
# ('Mission Viejo High School', '#898 Best Public High Schools in America', 'Saddleback Valley Unified School District', 'CA', '9-12', 4.0, '558', 'A', '2,407', '25:1')
# ('Fairlands Elementary School', '#1,066 Best Public Elementary Schools in America', 'Pleasanton Unified School District', 'CA', 'K-5', nan, nan, 'A', '785', '27:1')
# ('Thomas S Hart Middle School', '#416 Best Public Middle Schools in America', 'Pleasanton Unified School District', 'CA', '6-8', 3.0, '2', 'A', '1,167', '25:1')
# ('Design 39 Campus', '#1,076 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-7', nan, nan, 'A', '1,011', '27:1')
# ('Donlon Elementary School', '#1,086 Best Public Elementary Schools in America', 'Pleasanton Unified School District', 'CA', 'K-5', nan, nan, 'A', '825', '26:1')
# ('Rancho Cucamonga High School', '#910 Best Public High Schools in America', 'Chaffey Joint Union High School District', 'CA', '9-12', 4.0, '873', 'A', '3,444', '27:1')
# ('South Pointe Middle School', '#429 Best Public Middle Schools in America', 'Walnut Valley Unified School District', 'CA', '6-8', 4.0, '1', 'A', '917', '25:1')
# ('Castle Rock Elementary School', '#1,106 Best Public Elementary Schools in America', 'Walnut Valley Unified School District', 'CA', 'K-5', nan, nan, 'A', '624', '27:1')
# ('Middle College High School', '#913 Best Public High Schools in America', 'Lodi Unified School District', 'CA', '9-12', 3.5, '346', 'A', '246', '31:1')
# ('Wildwood Elementary School', '#1,115 Best Public Elementary Schools in America', 'Piedmont City Unified School District', 'CA', 'K-5', nan, nan, 'A', '312', '23:1')
# ('Santa Susana High School', '#915 Best Public High Schools in America', 'Simi Valley Unified School District', 'CA', '9-12', 4.0, '358', 'A', '1,271', '26:1')
# ('Foothill High School', '#918 Best Public High Schools in America', 'Tustin Unified School District', 'CA', '9-12', 4.0, '431', 'A', '2,510', '26:1')
# ('Poway High School', '#919 Best Public High Schools in America', 'Poway Unified School District', 'CA', '9-12', 4.0, '459', 'A', '2,250', '26:1')
# ('Solana Pacific Elementary School', '#1,127 Best Public Elementary Schools in America', 'Solana Beach Elementary School District', 'CA', '4-6', nan, nan, 'A', '576', '25:1')
# ('American High School', '#921 Best Public High Schools in America', 'Fremont Unified School District', 'CA', '9-12', 3.5, '349', 'A', '2,093', '24:1')
# ('Morning Creek Elementary School', '#1,135 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', 3.5, '3', 'A', '798', '25:1')
# ('Manhattan Beach Middle School', '#441 Best Public Middle Schools in America', 'Manhattan Beach Unified School District', 'CA', '6-8', 4.5, '18', 'A', '1,549', '25:1')
# ('Shoal Creek Elementary School', '#1,177 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', nan, nan, 'A', '594', '25:1')
# ('Albany Middle School', '#454 Best Public Middle Schools in America', 'Albany City Unified School District', 'CA', '6-8', 3.0, '1', 'A', '895', '19:1')
# ('Alisal Elementary School', '#1,183 Best Public Elementary Schools in America', 'Pleasanton Unified School District', 'CA', 'K-5', nan, nan, 'A', '628', '25:1')
# ('Plaza Vista', '#1,195 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-8', 4.5, '6', 'A', '940', '28:1')
# ('Bernardo Heights Middle School', '#462 Best Public Middle Schools in America', 'Poway Unified School District', 'CA', '6-8', 5.0, '2', 'A', '1,474', '26:1')
# ('Encinal Elementary School', '#1,199 Best Public Elementary Schools in America', 'Menlo Park City Elementary School District', 'CA', 'K-5', nan, nan, 'A', '765', '18:1')
# ('LA County High School for the Arts', '#947 Best Public High Schools in America', 'Los Angeles', 'CA', '9-12', 3.5, '157', 'A', '604', '8:1')
# ('Oak Creek Elementary School', '#1,201 Best Public Elementary Schools in America', 'Irvine Unified School District', 'CA', 'K-6', nan, nan, 'A', '879', '29:1')
# ('Marin Elementary School', '#1,208 Best Public Elementary Schools in America', 'Albany City Unified School District', 'CA', 'K-5', nan, nan, 'A', '497', '24:1')
# ('Arroyo Vista Elementary School', '#1,214 Best Public Elementary Schools in America', 'South Pasadena Unified School District', 'CA', 'K-5', nan, nan, 'A', '703', '23:1')
# ('Mira Catalina Elementary School', '#1,216 Best Public Elementary Schools in America', 'Palos Verdes Peninsula Unified School District', 'CA', 'K-5', 5.0, '1', 'A', '406', '25:1')
# ('Helix High School', '#953 Best Public High Schools in America', 'Grossmont Union High School District', 'CA', '9-12', 4.0, '687', 'A', '2,475', '26:1')
# ('El Segundo High School', '#954 Best Public High Schools in America', 'El Segundo Unified School District', 'CA', '9-12', 4.0, '492', 'A', '1,255', '24:1')
# ('Downtown Magnets High School', '#957 Best Public High Schools in America', 'Los Angeles Unified School District', 'CA', '9-12', 3.5, '309', 'A', '1,031', '23:1')
# ('Turtleback Elementary School', '#1,231 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', nan, nan, 'A', '604', '24:1')
# ('Newbury Park High School', '#961 Best Public High Schools in America', 'Conejo Valley Unified School District', 'CA', '9-12', 4.0, '466', 'A', '2,511', '26:1')
# ('Sharon Christa McAuliffe Middle School', '#477 Best Public Middle Schools in America', 'Los Alamitos Unified School District', 'CA', '6-8', 4.0, '6', 'A', '1,243', '27:1')
# ('San Luis Obispo High School', '#963 Best Public High Schools in America', 'San Luis Coastal Unified School District', 'CA', '9-12', 3.5, '148', 'A', '1,395', '21:1')
# ('Sundance Elementary School', '#1,244 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', nan, nan, 'A', '527', '23:1')
# ('Coyote Creek Elementary School', '#1,249 Best Public Elementary Schools in America', 'San Ramon Valley Unified School District', 'CA', 'K-5', nan, nan, 'A', '1,052', '25:1')
# ('Garden Road Elementary School', '#1,251 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', 5.0, '1', 'A', '447', '24:1')
# ('Tierra Bonita Elementary School', '#1,258 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', nan, nan, 'A', '470', '23:1')
# ('Argonaut Elementary School', '#1,265 Best Public Elementary Schools in America', 'Saratoga Union Elementary School District', 'CA', 'K-5', nan, nan, 'A', '391', '20:1')
# ('Laguna Hills High School', '#969 Best Public High Schools in America', 'Saddleback Valley Unified School District', 'CA', '9-12', 4.0, '335', 'A', '1,608', '26:1')
# ('Hart High School', '#970 Best Public High Schools in America', 'William S. Hart Union High School District', 'CA', '9-12', 4.0, '361', 'A', '2,299', '25:1')
# ('Midland Elementary School', '#1,279 Best Public Elementary Schools in America', 'Poway Unified School District', 'CA', 'K-5', nan, nan, 'A', '639', '27:1')
# ('Lunada Bay Elementary School', '#1,280 Best Public Elementary Schools in America', 'Palos Verdes Peninsula Unified School District', 'CA', 'K-5', nan, nan, 'A', '341', '24:1')
# ('Mountain Elementary School', '#1,282 Best Public Elementary Schools in America', 'Soquel', 'CA', 'K-6', nan, nan, 'A', '124', '18:1')
# ...
# ('Willows Community High School', nan, 'Willows Unified School District', 'CA', '9-12', nan, nan, 'NG', '25', '21:1')
# ('Eagle Mountain Elementary School', nan, 'Desert Center', 'CA', 'K-8', nan, nan, 'NG', '24', '12:1')
# ('Mid Valley Alternative Charter', nan, 'Kit Carson Union Elementary School District', 'CA', 'K-8', nan, nan, 'NG', '24', '12:1')
# ('Paramount Unified Community Day', nan, 'Paramount Unified School District', 'CA', '7-12', nan, nan, 'NG', '24', '7:1')
# ('Rincon High School', nan, 'Carpinteria Unified School District', 'CA', '9-12', nan, nan, 'NG', '24', '10:1')
# ('Steps Community Day', nan, 'Jurupa Unified School District', 'CA', '7-12', nan, nan, 'NG', '24', '6:1')
# ('Valley Oak Continuation High School', nan, 'Live Oak Unified School District', 'CA', '9-12', 4.0, '4', 'NG', '24', '20:1')
# ('Butte County Community School - LEAD', nan, 'Chico', 'CA', '7-12', nan, nan, 'NG', '23', '12:1')
# ('Chesnut High School', nan, 'Coalinga-Huron Joint Unified School District', 'CA', '9-12', nan, nan, 'NG', '23', '23:1')
# ('Freedom Academy of Imperial Valley', nan, 'Holtville Unified School District', 'CA', 'K-12', nan, nan, 'NG', '23', '12:1')
# ('Ingenuity Charter School', nan, 'San Diego Unified School District', 'CA', '6-12', nan, nan, 'NG', '23', '12:1')
# ('Pacifica Independent Home Study', nan, 'Pacifica School District', 'CA', 'K-8', nan, nan, 'NG', '23', '19:1')
# ('Walter J Katnich Community Day', nan, 'Lodi Unified School District', 'CA', '7-12', nan, nan, 'NG', '23', '12:1')
# ('Young Adult Program', nan, 'Fremont Unified School District', 'CA', '9-12', nan, nan, 'NG', '23', '12:1')
# ('Ahwahnee High School', nan, 'Yosemite Unified School District', 'CA', '9-12', nan, nan, 'NG', '22', '19:1')
# ('Center for Alternative Learning', nan, 'Chico Unified School District', 'CA', '6-12', nan, nan, 'NG', '22', '7:1')
# ('Flournoy Elementary School', nan, 'Flournoy', 'CA', 'K-8', nan, nan, 'NG', '22', '22:1')
# ('Jefferson High School', nan, 'Siskiyou Union High School District', 'CA', '9-12', nan, nan, 'NG', '22', '8:1')
# ('Life Learning Academy', nan, 'San Francisco Unified School District', 'CA', '9-12', 5.0, '1', 'NG', '22', '8:1')
# ('Mid Valley High School', nan, 'Williams Unified School District', 'CA', '10-12', nan, nan, 'NG', '22', '20:1')
# ('Mountain Vista Educational Center', nan, 'Madera Unified School District', 'CA', nan, nan, nan, 'NG', '22', '11:1')
# ('Owens Valley High School', nan, 'Owens Valley Unified School District', 'CA', '9-12', 4.5, '2', 'NG', '22', '8:1')
# ('Pathway Community Day', nan, 'Central Unified School District', 'CA', '7-12', nan, nan, 'NG', '22', '4:1')
# ('Alternative Learning Center', nan, 'San Bernardino City Unified School District', 'CA', '1-12', nan, nan, 'NG', '21', '11:1')
# ('Clearlake Creativity', nan, 'Clearlake', 'CA', 'K-12', nan, nan, 'NG', '21', '7:1')
# ('Duncan-Russell Continuation', nan, 'Tracy Joint Unified School District', 'CA', '10-12', nan, nan, 'NG', '21', '21:1')
# ('Gateway High School', nan, 'Chowchilla Union High School District', 'CA', '9-12', nan, nan, 'NG', '21', '11:1')
# ('Lassen County Special Education', nan, 'Susanville', 'CA', 'K-12', nan, nan, 'NG', '21', '3:1')
# ('Magnolia Park', nan, 'Burbank Unified School District', 'CA', '6-12', nan, nan, 'NG', '21', '9:1')
# ('Pacific Valley (K-12)', nan, 'Big Sur Unified School District', 'CA', 'K-12', 4.0, '1', 'NG', '21', '4:1')
# ('Tuolumne County Community/Isp', nan, 'Sonora', 'CA', 'K-12', nan, nan, 'NG', '21', '15:1')
# ('Burbank Community Day School', nan, 'Burbank Unified School District', 'CA', '7-12', nan, nan, 'NG', '20', '5:1')
# ('Community Day', nan, 'Claremont Unified School District', 'CA', '7-12', nan, nan, 'NG', '20', '17:1')
# ('Downieville Junior-Senior High School', nan, 'Sierra-Plumas Joint Unified School District', 'CA', '7-12', 3.5, '3', 'NG', '20', '9:1')
# ('Heritage Valley Independent Study', nan, 'Fillmore Unified School District', 'CA', 'K-12', nan, nan, 'NG', '20', '20:1')
# ('Method Schools K-8', nan, 'Acton-Agua Dulce Unified School District', 'CA', 'K-8', nan, nan, 'NG', '20', '17:1')
# ('Mountain View High School', nan, 'Fall River Joint Unified School District', 'CA', '9-12', 4.0, '1', 'NG', '20', '20:1')
# ('Sierra Vista', nan, 'Newcastle', 'CA', 'K-12', nan, nan, 'NG', '20', '10:1')
# ('Valley Teen Ranch Community Day', nan, 'Golden Valley Unified School District', 'CA', '7-12', nan, nan, 'NG', '20', '10:1')
# ('Vine Street Community Day', nan, 'Porterville Unified School District', 'CA', '7-12', nan, nan, 'NG', '20', '13:1')
# ('CCUSD iAcademy', nan, 'Culver City Unified School District', 'CA', 'K-12', 4.5, '2', 'NG', '19', '19:1')
# ('Calico Continuation High School', nan, 'Silver Valley Unified School District', 'CA', '9-12', nan, nan, 'NG', '19', '19:1')
# ('Indian Diggings Elementary School', nan, 'Somerset', 'CA', 'K-8', nan, nan, 'NG', '19', '19:1')
# ('Lewis Opportunity', nan, 'Santa Rosa High School District', 'CA', '7-12', nan, nan, 'NG', '19', '4:1')
# ('Mokelumne High School', nan, 'River Delta Joint Unified School District', 'CA', '9-12', nan, nan, 'NG', '19', '19:1')
# ('Mountain House Elementary School', nan, 'Byron', 'CA', 'K-8', nan, nan, 'NG', '19', '19:1')
# ('Palm Canyon', nan, 'Hacienda La Puente Unified School District', 'CA', '9-12', nan, nan, 'NG', '19', '10:1')
# ('Amador County Community', nan, 'Sutter Creek', 'CA', '1-12', nan, nan, 'NG', '18', '8:1')
# ('Carr Lake Community Day', nan, 'Salinas Union High School District', 'CA', '7-12', nan, nan, 'NG', '18', '18:1')
# ('Chino Valley Learning Academy', nan, 'Chino Valley Unified School District', 'CA', '7-12', nan, nan, 'NG', '18', '9:1')
# ('Colusa Alternative High School', nan, 'Colusa Unified School District', 'CA', '9-12', nan, nan, 'NG', '18', '18:1')
# ('Community Day', nan, 'Oakland Unified School District', 'CA', '9-12', nan, nan, 'NG', '18', '5:1')
# ('Honey Run Academy Secondary School', nan, 'Paradise Unified School District', 'CA', '7-12', nan, nan, 'NG', '18', '10:1')
# ('Hot Springs Elementary School', nan, 'California Hot Springs', 'CA', 'K-8', nan, nan, 'NG', '18', '18:1')
# ('Johanna Echols-Hansen High School', nan, 'Cloverdale Unified School District', 'CA', '9-12', nan, nan, 'NG', '18', '18:1')
# ('Klamath River Elementary School', nan, 'Horse Creek', 'CA', 'K-8', nan, nan, 'NG', '18', '18:1')
# ('Laguna Elementary School', nan, 'Petaluma', 'CA', 'K-6', nan, nan, 'NG', '18', '12:1')
# ('Lighthouse Community Day', nan, 'Fort Bragg Unified School District', 'CA', '9-12', nan, nan, 'NG', '18', '9:1')
# ('Mountain Oaks High School', nan, 'Chawanakee Unified School District', 'CA', '9-12', nan, nan, 'NG', '18', '6:1')
# ('Palm Academy', nan, 'Coronado Unified School District', 'CA', '9-12', 3.5, '4', 'NG', '18', '9:1')
# ('Arbuckle Alternative High School', nan, 'Pierce Joint Unified School District', 'CA', '9-12', nan, nan, 'NG', '17', '17:1')
# ('Camden Community Day', nan, 'Campbell Union High School District', 'CA', '9-12', nan, nan, 'NG', '17', '5:1')
# ('Campo High School', nan, 'Mountain Empire Unified School District', 'CA', '9-12', nan, nan, 'NG', '17', '9:1')
# ('Clover Valley High School', nan, 'Upper Lake Union High School District', 'CA', '9-12', nan, nan, 'NG', '17', '17:1')
# ('Death Valley High Academy', nan, 'Death Valley Unified School District', 'CA', '7-12', 3.5, '2', 'NG', '17', '5:1')
# ('Forks of Salmon Elementary School', nan, 'Forks Of Salmon', 'CA', 'K-8', nan, nan, 'NG', '17', '17:1')
# ('John Vierra High School', nan, 'Bret Harte Union High School District', 'CA', '9-12', nan, nan, 'NG', '17', '17:1')
# ('Sam Webb Continuation', nan, 'Holtville Unified School District', 'CA', '9-12', nan, nan, 'NG', '17', '10:1')
# ('Blue Heron', nan, 'Konocti Unified School District', 'CA', '9-11', nan, nan, 'NG', '16', '16:1')
# ('Bogus Elementary School', nan, 'Montague', 'CA', 'K-8', nan, nan, 'NG', '16', '16:1')
# ('Ed Donaldson Education Center', nan, 'Kelseyville Unified School District', 'CA', '9-12', 4.0, '1', 'NG', '16', '16:1')
# ('Laurel High School', nan, 'Los Alamitos Unified School District', 'CA', '9-12', 4.5, '2', 'NG', '16', '15:1')
# ('Macgregor High School', nan, 'Albany City Unified School District', 'CA', '10-12', nan, nan, 'NG', '16', '16:1')
# ('Madison Community High School', nan, 'Esparto Unified School District', 'CA', '9-12', nan, nan, 'NG', '16', '11:1')
# ('Mendota Continuation High School', nan, 'Mendota Unified School District', 'CA', '9-12', nan, nan, 'NG', '16', '8:1')
# ('Mission Community Day', nan, 'Corcoran Joint Unified School District', 'CA', '6-12', nan, nan, 'NG', '16', '8:1')
# ('Orick Elementary School', nan, 'Orick', 'CA', 'K-8', nan, nan, 'NG', '16', '9:1')
# ('Pioneer High School', nan, 'Gustine Unified School District', 'CA', '9-12', nan, nan, 'NG', '16', '—')
# ('Rowland Assistive Technology Academy', nan, 'Rowland Unified School District', 'CA', 'K-12', nan, nan, 'NG', '16', '8:1')
# ('Silver Fork Elementary School', nan, 'Kyburz', 'CA', 'K-8', nan, nan, 'NG', '16', '8:1')
# ('Southern Humboldt Community', nan, 'Garberville', 'CA', '7-12', nan, nan, 'NG', '16', '16:1')
# ('Spring Hill High School', nan, 'Mariposa County Unified School District', 'CA', '9-12', nan, nan, 'NG', '16', '10:1')
# ('Transitional Learning Center (Continuation)', nan, 'Lake Tahoe Unified School District', 'CA', '9-12', nan, nan, 'NG', '16', '7:1')
# ('Willow Grove Elementary School', nan, 'Paicines', 'CA', 'K-8', nan, nan, 'NG', '16', '16:1')
# ('Community High School', nan, 'Pacific Grove Unified School District', 'CA', '9-12', nan, nan, 'NG', '15', '8:1')
# ('Elkins Elementary School', nan, 'Paskenta', 'CA', 'K-8', nan, nan, 'NG', '15', '15:1')
# ('Gene Drevno Community Day', nan, 'Torrance Unified School District', 'CA', '7-12', nan, nan, 'NG', '15', '15:1')
# ('Hesperia Community Day', nan, 'Hesperia Unified School District', 'CA', '7-12', nan, nan, 'NG', '15', '8:1')
# ('Indian Springs Elementary School', nan, 'Big Bend', 'CA', 'K-8', nan, nan, 'NG', '15', '8:1')
# ('Loconoma Valley High School', nan, 'Middletown Unified School District', 'CA', '9-12', nan, nan, 'NG', '15', '14:1')
# ('MARC High School', nan, 'Caruthers Unified School District', 'CA', '9-12', nan, nan, 'NG', '15', '8:1')
# ('Palisades High School', nan, 'Calistoga Joint Unified School District', 'CA', '9-12', nan, nan, 'NG', '15', '15:1')
# ('Rio Del Rey High School', nan, 'Golden Plains Unified School District', 'CA', '9-12', nan, nan, 'NG', '15', '15:1')
# ('Shattuck Independent Study', nan, 'Delhi Unified School District', 'CA', '9-12', nan, nan, 'NG', '15', '15:1')
# ('Trinity County Home', nan, 'Weaverville', 'CA', 'K-8', nan, nan, 'NG', '15', '15:1')
# ('Academy for Change', nan, 'Chico Unified School District', 'CA', '7-12', nan, nan, 'NG', '14', '7:1')
# ('Community Day', nan, 'Benicia Unified School District', 'CA', '7-12', nan, nan, 'NG', '14', '14:1')
# ('Dr Bob Forinash Community Day', nan, 'Lompoc Unified School District', 'CA', '7-12', nan, nan, 'NG', '14', '11:1')
# ('Freedom High School', nan, 'Shasta Union High School District', 'CA', '9-12', nan, nan, 'NG', '14', '14:1')
# ('Independent Study Program', nan, 'Mountain View Whisman School District', 'CA', 'K-8', nan, nan, 'NG', '14', '14:1')
# ('Kashia Elementary School', nan, 'Stewarts Point', 'CA', 'K-8', nan, nan, 'NG', '14', '14:1')
# ('Leggett Valley High School', nan, 'Leggett Valley Unified School District', 'CA', '9-12', 4.0, '4', 'NG', '14', '6:1')
# ('Marce Becerra Academy', nan, 'Healdsburg Unified School District', 'CA', '9-12', nan, nan, 'NG', '14', '12:1')
# ('Middletown Community Day', nan, 'Middletown Unified School District', 'CA', '7-12', nan, nan, 'NG', '14', '—')
# ('Oakendell Community', nan, 'San Andreas', 'CA', '6-12', nan, nan, 'NG', '14', '14:1')
# ('Pomona Community Day', nan, 'Pomona Unified School District', 'CA', '7-12', nan, nan, 'NG', '14', '6:1')
# ('Sierra High School', nan, 'Mammoth Unified School District', 'CA', '10-12', nan, nan, 'NG', '14', '14:1')
# ('Alternative Learning Academy at Conley-Caraballo High', nan, 'New Haven Unified School District', 'CA', '9-12', 4.5, '8', 'NG', '13', '13:1')
# ('Bellflower Alternative Education Center', nan, 'Bellflower Unified School District', 'CA', 'K-12', nan, nan, 'NG', '13', '4:1')
# ('Bridges Community Day', nan, 'Capistrano Unified School District', 'CA', '7-12', nan, nan, 'NG', '13', '4:1')
# ('Easton Continuation High School', nan, 'Washington Unified School District', 'CA', '9-12', nan, nan, 'NG', '13', '8:1')
# ('Fowler Academy', nan, 'Fowler Unified School District', 'CA', '7-12', nan, nan, 'NG', '13', '12:1')
# ('McFarland Independent', nan, 'McFarland Unified School District', 'CA', '9-12', nan, nan, 'NG', '13', '13:1')
# ('Modoc County Special Education', nan, 'Alturas', 'CA', 'K-12', nan, nan, 'NG', '13', '1:1')
# ('Mountain View High School', nan, 'Lucerne Valley Unified School District', 'CA', '7-12', nan, nan, 'NG', '13', '13:1')
# ('Osprey Learning Center', nan, 'Southern Humboldt Joint Unified School District', 'CA', '9-12', nan, nan, 'NG', '13', '13:1')
# ('School of Opportunity', nan, 'Barstow Unified School District', 'CA', '7-12', nan, nan, 'NG', '13', '13:1')
# ('South Bay Academy Community Day', nan, 'Centinela Valley Union High School District', 'CA', '9-12', nan, nan, 'NG', '13', '11:1')
# ('Tri-City Community Day School', nan, 'San Bernardino City Unified School District', 'CA', '7-12', nan, nan, 'NG', '13', '2:1')
# ('Whitmore Charter School of Personalized Learning', nan, 'Ceres Unified School District', 'CA', 'K-12', nan, nan, 'NG', '13', '13:1')
# ('Carmel Valley High School', nan, 'Carmel Unified School District', 'CA', '9-12', nan, nan, 'NG', '12', '5:1')
# ('Centennial Independent Study', nan, 'Golden Valley Unified School District', 'CA', '1-12', nan, nan, 'NG', '12', '9:1')
# ('Divide High School', nan, 'Black Oak Mine Unified School District', 'CA', '9-12', nan, nan, 'NG', '12', '12:1')
# ('Division of Unaccompanied Children&aposs Services', nan, 'Fairfield', 'CA', '7-12', nan, nan, 'NG', '12', '12:1')
# ('Long Barn High School', nan, 'Summerville Union High School District', 'CA', '9-12', nan, nan, 'NG', '12', '12:1')
# ('Maple Creek Elementary School', nan, 'Korbel', 'CA', 'K-8', nan, nan, 'NG', '12', '8:1')
# ('McCloud High School', nan, 'Siskiyou Union High School District', 'CA', '9-12', nan, nan, 'NG', '12', '6:1')
# ('Mendocino Alternative School', nan, 'Mendocino Unified School District', 'CA', 'K-12', nan, nan, 'NG', '12', '12:1')
# ('Moreno High School', nan, 'Beverly Hills Unified School District', 'CA', '9-12', nan, nan, 'NG', '12', '5:1')
# ('Mt Burney Special Education Center', nan, 'Fall River Joint Unified School District', 'CA', 'K-12', nan, nan, 'NG', '12', '12:1')
# ('Needles Community Day', nan, 'Needles Unified School District', 'CA', '6-12', nan, nan, 'NG', '12', '12:1')
# ('Palo Verde Valley Community Day', nan, 'Palo Verde Unified School District', 'CA', '7-12', nan, nan, 'NG', '12', '12:1')
# ('Rancheria Continuation', nan, 'Anderson Valley Unified School District', 'CA', '9-12', nan, nan, 'NG', '12', '12:1')
# ('Valley Community Day', nan, 'Hacienda La Puente Unified School District', 'CA', '7-12', nan, nan, 'NG', '12', '6:1')
# ('Vista Adult Transition Center', nan, 'Vista Unified School District', 'CA', '9-11', nan, nan, 'NG', '12', '14:1')
# ('Diablo Community Day', nan, 'Mt. Diablo Unified School District', 'CA', '7-12', nan, nan, 'NG', '11', '4:1')
# ('Horizon High School', nan, 'Riverdale Joint Unified School District', 'CA', '9-12', nan, nan, 'NG', '11', '11:1')
# ('Independence Continuation High School', nan, 'Golden Valley Unified School District', 'CA', '10-12', nan, nan, 'NG', '11', '5:1')
# ('Leffingwell High School', nan, 'Coast Unified School District', 'CA', '9-12', nan, nan, 'NG', '11', '9:1')
# ('River Delta High/Elementary (Alternative)', nan, 'River Delta Joint Unified School District', 'CA', 'K-12', nan, nan, 'NG', '11', '11:1')
# ('Connecting Waters Charter School East Bay', nan, 'Waterford Unified School District', 'CA', 'PK, K-12', 5.0, '1', 'NG', '—', '—')

# %% [markdown]
# #### Create csv and write the data into it.
# @Author : Vidhi & Reetika

# %%
# open a csv file with append, so old data will not be erased
with open('schoolRating.csv', 'w') as csv_file:
  writer = csv.writer(csv_file)
  writer.writerow(['School Name', 'Rank in America','District','State', 'School Grade Level','Rating','User Reviews','Overall Niche Grade','School Strength','Student Teacher Ratio', 'Extracted Date'])
 # The for loop
  for schoolName, schoolRank,schoolDistrict,schoolState, schoolGradeLevel ,rating,reviewCount,schoolGrade,schoolStrength,studentTeacherRatio in textContent:
    writer.writerow([schoolName, schoolRank, schoolDistrict,schoolState, schoolGradeLevel,rating,reviewCount,schoolGrade,schoolStrength,studentTeacherRatio, datetime.now()])

# %% [markdown]
# #### Read the created dataset

# %%
#Read csv
df_itemlist = pd.read_csv('schoolRating.csv')
df_itemlist.shape
# Out:
# (9647, 11)

# %%
df_itemlist.head(45)
# Out:
#                                     School Name  \
# 0                          Canyon Crest Academy
# 1                      Henry M Gunn High School
# 2                              Troy High School
# 3                         Palo Alto High School
# 4                         Miramonte High School
# 5                         Northwood High School
# 6                          Saratoga High School
# 7                      Torrey Pines High School
# 8            Palos Verdes Peninsula High School
# 9                         Los Altos High School
# 10                         Westview High School
# 11  California Academy of Mathematics & Science
# 12                        Los Gatos High School
# 13                         Lynbrook High School
# 14            Granada Hills Charter High School
# 15                       Campolindo High School
# 16                       San Marino High School
# 17                        La Canada High School
# 18                           Carmel High School
# 19                           Lowell High School
# 20                          Redwood High School
# 21                          Arcadia High School
# 22                       University High School
# 23             Orange County School of the Arts
# 24                    Amador Valley High School
# 25                       University High School
# 26                               Oxford Academy
# 27                          Whitney High School
# 28                 Dougherty Valley High School
# 29                           Walnut High School
# 30                       Academy of the Canyons
# 31                         Westlake High School
# 32                      Monta Vista High School
# 33                    Mountain View High School
# 34                           Aragon High School
# 35                        Del Norte High School
# 36                       Burlingame High School
# 37                 Mission San Jose High School
# 38                   Corona Del Mar High School
# 39            South Pasadena Senior High School
# 40                        Cupertino High School
# 41                 El Carmelo Elementary School
# 42          Jane Lathrop Stanford Middle School
# 43                           Leland High School
# 44                   Duveneck Elementary School
#
#                                   Rank in America  \
# 0         #16 Best Public High Schools in America
# 1         #21 Best Public High Schools in America
# 2         #42 Best Public High Schools in America
# 3         #51 Best Public High Schools in America
# 4         #57 Best Public High Schools in America
# 5         #67 Best Public High Schools in America
# 6         #77 Best Public High Schools in America
# 7         #80 Best Public High Schools in America
# 8         #94 Best Public High Schools in America
# 9        #101 Best Public High Schools in America
# 10       #105 Best Public High Schools in America
# 11       #106 Best Public High Schools in America
# 12       #108 Best Public High Schools in America
# 13       #117 Best Public High Schools in America
# 14       #120 Best Public High Schools in America
# 15       #128 Best Public High Schools in America
# 16       #129 Best Public High Schools in America
# 17       #134 Best Public High Schools in America
# 18       #152 Best Public High Schools in America
# 19       #156 Best Public High Schools in America
# 20       #160 Best Public High Schools in America
# 21       #163 Best Public High Schools in America
# 22       #174 Best Public High Schools in America
# 23       #182 Best Public High Schools in America
# 24       #184 Best Public High Schools in America
# 25       #199 Best Public High Schools in America
# 26       #206 Best Public High Schools in America
# 27       #210 Best Public High Schools in America
# 28       #211 Best Public High Schools in America
# 29       #226 Best Public High Schools in America
# 30       #228 Best Public High Schools in America
# 31       #233 Best Public High Schools in America
# 32       #251 Best Public High Schools in America
# 33       #254 Best Public High Schools in America
# 34       #259 Best Public High Schools in America
# 35       #260 Best Public High Schools in America
# 36       #262 Best Public High Schools in America
# 37       #266 Best Public High Schools in America
# 38       #270 Best Public High Schools in America
# 39       #274 Best Public High Schools in America
# 40       #275 Best Public High Schools in America
# 41  #18 Best Public Elementary Schools in America
# 42      #23 Best Public Middle Schools in America
# 43       #295 Best Public High Schools in America
# 44  #21 Best Public Elementary Schools in America
#
#                                              District State  \
# 0             San Dieguito Union High School District    CA
# 1                   Palo Alto Unified School District    CA
# 2          Fullerton Joint Union High School District    CA
# 3                   Palo Alto Unified School District    CA
# 4                 Acalanes Union High School District    CA
# 5                      Irvine Unified School District    CA
# 6   Los Gatos-Saratoga Joint Union High School Dis...    CA
# 7             San Dieguito Union High School District    CA
# 8      Palos Verdes Peninsula Unified School District    CA
# 9   Mountain View-Los Altos Union High School Dist...    CA
# 10                      Poway Unified School District    CA
# 11                 Long Beach Unified School District    CA
# 12  Los Gatos-Saratoga Joint Union High School Dis...    CA
# 13                 Fremont Union High School District    CA
# 14                Los Angeles Unified School District    CA
# 15                Acalanes Union High School District    CA
# 16                 San Marino Unified School District    CA
# 17                  La Canada Unified School District    CA
# 18                     Carmel Unified School District    CA
# 19              San Francisco Unified School District    CA
# 20               Tamalpais Union High School District    CA
# 21                    Arcadia Unified School District    CA
# 22                     Fresno Unified School District    CA
# 23                  Santa Ana Unified School District    CA
# 24                 Pleasanton Unified School District    CA
# 25                     Irvine Unified School District    CA
# 26                 Anaheim Union High School District    CA
# 27                        ABC Unified School District    CA
# 28           San Ramon Valley Unified School District    CA
# 29              Walnut Valley Unified School District    CA
# 30         William S. Hart Union High School District    CA
# 31              Conejo Valley Unified School District    CA
# 32                 Fremont Union High School District    CA
# 33  Mountain View-Los Altos Union High School Dist...    CA
# 34               San Mateo Union High School District    CA
# 35                      Poway Unified School District    CA
# 36               San Mateo Union High School District    CA
# 37                    Fremont Unified School District    CA
# 38               Newport-Mesa Unified School District    CA
# 39             South Pasadena Unified School District    CA
# 40                 Fremont Union High School District    CA
# 41                  Palo Alto Unified School District    CA
# 42                  Palo Alto Unified School District    CA
# 43                   San Jose Unified School District    CA
# 44                  Palo Alto Unified School District    CA
#
#    School Grade Level  Rating User Reviews Overall Niche Grade  \
# 0                9-12     4.5          495                  A+
# 1                9-12     4.0          260                  A+
# 2                9-12     4.0          794                  A+
# 3                9-12     4.0          280                  A+
# 4                9-12     4.0          190                  A+
# 5                9-12     4.0          457                  A+
# 6                9-12     4.0          157                  A+
# 7                9-12     4.0          401                  A+
# 8                9-12     4.0          576                  A+
# 9                9-12     4.0          263                  A+
# 10               9-12     4.0          574                  A+
# 11               9-12     4.0          398                  A+
# 12               9-12     4.0          222                  A+
# 13               9-12     3.5          418                  A+
# 14               9-12     4.0        1,230                  A+
# 15               9-12     4.0          236                  A+
# 16               9-12     4.0          244                  A+
# 17               7-12     3.5          308                  A+
# 18               9-12     4.0          205                  A+
# 19               9-12     3.5          890                  A+
# 20               9-12     4.0          187                  A+
# 21               9-12     4.0          984                  A+
# 22               9-12     4.0          220                  A+
# 23               7-12     4.0          459                  A+
# 24               9-12     4.0          441                  A+
# 25               9-12     4.0          437                  A+
# 26               7-12     3.5          572                  A+
# 27               7-12     3.5          333                  A+
# 28               9-12     3.5          578                  A+
# 29               9-12     4.0          537                  A+
# 30               9-12     4.0          203                  A+
# 31               9-12     4.0          419                  A+
# 32               9-12     3.5          353                  A+
# 33               9-12     4.0          248                  A+
# 34               9-12     4.0          235                  A+
# 35               9-12     4.0          328                  A+
# 36               9-12     4.0          204                  A+
# 37               9-12     3.5          336                  A+
# 38               7-12     4.0          247                  A+
# 39               9-12     3.5          392                  A+
# 40               9-12     4.0          402                  A+
# 41                K-5     5.0            1                  A+
# 42                6-8     3.5            6                  A+
# 43               9-12     3.5          260                  A+
# 44                K-5     NaN          NaN                  A+
#
#    School Strength Student Teacher Ratio              Extracted Date
# 0            2,255                  26:1  2019-03-19 00:43:04.494717
# 1            1,918                  19:1  2019-03-19 00:43:04.494741
# 2            2,755                  27:1  2019-03-19 00:43:04.494751
# 3            1,993                  19:1  2019-03-19 00:43:04.494760
# 4            1,232                  20:1  2019-03-19 00:43:04.494768
# 5            2,240                  28:1  2019-03-19 00:43:04.494776
# 6            1,305                  18:1  2019-03-19 00:43:04.494783
# 7            2,601                  27:1  2019-03-19 00:43:04.494791
# 8            2,519                  26:1  2019-03-19 00:43:04.494821
# 9            2,039                  21:1  2019-03-19 00:43:04.494830
# 10           2,304                  28:1  2019-03-19 00:43:04.494838
# 11             681                  30:1  2019-03-19 00:43:04.494846
# 12           1,975                  22:1  2019-03-19 00:43:04.494855
# 13           1,766                  24:1  2019-03-19 00:43:04.494862
# 14           4,650                  19:1  2019-03-19 00:43:04.494870
# 15           1,300                  21:1  2019-03-19 00:43:04.494878
# 16           1,200                  21:1  2019-03-19 00:43:04.494886
# 17           2,075                  25:1  2019-03-19 00:43:04.494893
# 18             857                  17:1  2019-03-19 00:43:04.494901
# 19           2,685                  21:1  2019-03-19 00:43:04.494908
# 20           1,770                  19:1  2019-03-19 00:43:04.494916
# 21           3,424                  25:1  2019-03-19 00:43:04.494939
# 22             482                  25:1  2019-03-19 00:43:04.494945
# 23           2,096                  30:1  2019-03-19 00:43:04.494952
# 24           2,628                  25:1  2019-03-19 00:43:04.494960
# 25           2,617                  27:1  2019-03-19 00:43:04.494968
# 26           1,208                  28:1  2019-03-19 00:43:04.494976
# 27           1,011                  25:1  2019-03-19 00:43:04.494984
# 28           2,759                  24:1  2019-03-19 00:43:04.494991
# 29           2,675                  24:1  2019-03-19 00:43:04.494999
# 30             395                  33:1  2019-03-19 00:43:04.495006
# 31           2,370                  28:1  2019-03-19 00:43:04.495013
# 32           2,322                  26:1  2019-03-19 00:43:04.495020
# 33           1,857                  20:1  2019-03-19 00:43:04.495027
# 34           1,473                  21:1  2019-03-19 00:43:04.495035
# 35           2,032                  28:1  2019-03-19 00:43:04.495042
# 36           1,339                  20:1  2019-03-19 00:43:04.495049
# 37           2,069                  25:1  2019-03-19 00:43:04.495056
# 38           2,580                  28:1  2019-03-19 00:43:04.495063
# 39           1,528                  22:1  2019-03-19 00:43:04.495070
# 40           2,233                  25:1  2019-03-19 00:43:04.495077
# 41             395                  21:1  2019-03-19 00:43:04.495084
# 42           1,111                  18:1  2019-03-19 00:43:04.495090
# 43           1,807                  25:1  2019-03-19 00:43:04.495098
# 44             479                  20:1  2019-03-19 00:43:04.495104
